# %%
# !pip install ultralytics supervision opencv-python-headless -q
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.117 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.9/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="LfROP6XSytfhhlAPUZ4U")
project = rf.workspace("rishabh-kumar-7sm3h").project("anti-drone-2-80wfp")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 27.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 56.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 102.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 5.0.0.93
#     Uninstalling opencv-python-headless-5.0.0.93:
#       Successfully uninstalled opencv-python-headless-5.0.0.93
#   Attempting uninstall: typer
#     Found existing installation: typer 0.26.8
#     Uninstalling typer-0.26.8:
#       Successfully uninstalled typer-0.26.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# ---------------------------------------------------------------------------
# ...

# %%
# after restarting runtime, re-run install cell, then:
from roboflow import Roboflow
rf = Roboflow(api_key="LfROP6XSytfhhlAPUZ4U")
project = rf.workspace("rishabh-kumar-7sm3h").project("anti-drone-2-80wfp")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_840/1277695421.py in <cell line: 0>()
#       1 # after restarting runtime, re-run install cell, then:
# ----> 2 from roboflow import Roboflow
#       3 rf = Roboflow(api_key="LfROP6XSytfhhlAPUZ4U")
#       4 project = rf.workspace("rishabh-kumar-7sm3h").project("anti-drone-2-80wfp")
#       5 version = project.version(1)
#
# ModuleNotFoundError: No module named 'roboflow'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install roboflow supervision opencv-python-headless ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.3/373.3 kB 33.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 77.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 18.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 52.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 97.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 4.0 MB/s eta 0:00:00

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="LfROP6XSytfhhlAPUZ4U")
project = rf.workspace("rishabh-kumar-7sm3h").project("anti-drone-2-80wfp")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Anti-drone-2-1 in yolov8:: 100%|██████████| 8445/8445 [00:01<00:00, 5575.11it/s]
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # nano model - fast, good for MVP

results = model.train(
    data='Anti-drone-2-1/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    name='drone_detector_v1'
)
# Out:
# ...
# Ultralytics 8.4.117 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
metrics = model.val(data='Anti-drone-2-1/data.yaml', split='test')
print(f"Precision: {metrics.box.mp:.3f}")
print(f"Recall: {metrics.box.mr:.3f}")
print(f"mAP50: {metrics.box.map50:.3f}")
print(f"mAP50-95: {metrics.box.map:.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_566/425651095.py in <cell line: 0>()
# ----> 1 metrics = model.val(data='Anti-drone-2-1/data.yaml', split='test')
#       2 print(f"Precision: {metrics.box.mp:.3f}")
#       3 print(f"Recall: {metrics.box.mr:.3f}")
#       4 print(f"mAP50: {metrics.box.map50:.3f}")
#       5 print(f"mAP50-95: {metrics.box.map:.3f}")
#
# NameError: name 'model' is not defined

# %%
import os
print(os.path.exists('/content/runs/detect/drone_detector_v1/weights/best.pt'))
print(os.path.exists('/content/Anti-drone-2-1/data.yaml'))
# Out:
# False
# False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install roboflow supervision opencv-python-headless ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.3/373.3 kB 29.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 75.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 25.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 77.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 127.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.2 MB/s eta 0:00:00

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="LfROP6XSytfhhlAPUZ4U")
project = rf.workspace("rishabh-kumar-7sm3h").project("anti-drone-2-80wfp")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Anti-drone-2-1 in yolov8:: 100%|██████████| 8445/8445 [00:02<00:00, 4107.40it/s]
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data='Anti-drone-2-1/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    name='drone_detector_v1',
    project='/content/drive/MyDrive/drone_project/runs'   # <-- saves directly to your Drive, survives disconnects
)
# Out:
# ...
# Ultralytics 8.4.117 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/drone_project/runs/drone_detector_v1/weights/best.pt')

metrics = model.val(data='Anti-drone-2-1/data.yaml', split='test')
print(f"Precision: {metrics.box.mp:.3f}")
print(f"Recall: {metrics.box.mr:.3f}")
print(f"mAP50: {metrics.box.map50:.3f}")
print(f"mAP50-95: {metrics.box.map:.3f}")
# Out:
# Ultralytics 8.4.117 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1475.8±975.0 MB/s, size: 54.3 KB)
# val: Scanning /content/Anti-drone-2-1/test/labels... 127 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 127/127 2.1Kit/s 0.1s
# val: New cache created: /content/Anti-drone-2-1/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.2it/s 2.5s
#                    all        127        127      0.977      0.825      0.878      0.703
#            Competition         34         34      0.984      0.647      0.826      0.547
#             Fixed-wing         62         62      0.961      0.968      0.979      0.832
#            Multicopter         22         22       0.99      0.909      0.905      0.719
# ...

# %%
import os

print("Dataset present:", os.path.exists('/content/Anti-drone-2-1/data.yaml'))
print("Trained weights (local):", os.path.exists('/content/drive/MyDrive/drone_project/runs/drone_detector_v1/weights/best.pt'))

try:
    print("model variable exists:", 'model' in dir())
except:
    pass

import torch
print("GPU available:", torch.cuda.is_available())
# Out:
# Dataset present: False
# Trained weights (local): False
# model variable exists: False
# GPU available: False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print(os.path.exists('/content/drive/MyDrive/drone_project/runs/drone_detector_v1/weights/best.pt'))
# Out:
# True

# %%
# !pip install ultralytics opencv-python-headless -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 31.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 3.6 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
model = YOLO('/content/drive/MyDrive/drone_project/runs/drone_detector_v1/weights/best.pt')
model.to('cpu')
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
# ...

# %%
import os
print(os.path.exists('/content/drive/MyDrive/drone_project/synthetic_test.mp4'))
# Out:
# False

# %%
# !pip install roboflow -q
from roboflow import Roboflow
rf = Roboflow(api_key="LfROP6XSytfhhlAPUZ4U")
project = rf.workspace("rishabh-kumar-7sm3h").project("anti-drone-2-80wfp")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 66.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 108.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 3.9 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Anti-drone-2-1 in yolov8:: 100%|██████████| 8445/8445 [00:04<00:00, 1988.95it/s]

# %%
import cv2, glob

image_paths = sorted(glob.glob('/content/Anti-drone-2-1/test/images/*.jpg'))
frame = cv2.imread(image_paths[0])
h, w, _ = frame.shape

out = cv2.VideoWriter('/content/drive/MyDrive/drone_project/synthetic_test.mp4',
                       cv2.VideoWriter_fourcc(*'mp4v'), 2, (w, h))

for path in image_paths:
    img = cv2.imread(path)
    img = cv2.resize(img, (w, h))
    out.write(img)

out.release()
print("Synthetic video created")
# Out:
# Synthetic video created

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/drone_project/runs/drone_detector_v1/weights/best.pt')
model.to('cpu')

cap = cv2.VideoCapture('/content/drive/MyDrive/drone_project/synthetic_test.mp4')
fps = int(cap.get(cv2.CAP_PROP_FPS))
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

out = cv2.VideoWriter('/content/drive/MyDrive/drone_project/output_detected.mp4',
                       cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    results = model(frame, verbose=False)
    annotated_frame = results[0].plot()
    out.write(annotated_frame)

cap.release()
out.release()
print("Inference video saved to Drive")
# Out:
# Inference video saved to Drive

# %%
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt

model = YOLO('/content/drive/MyDrive/drone_project/runs/drone_detector_v1/weights/best.pt')
model.to('cpu')

cap = cv2.VideoCapture('/content/drive/MyDrive/drone_project/output_detected.mp4')
ret, frame = cap.read()
cap.release()

# Convert BGR (OpenCV) to RGB (matplotlib) for correct color display
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,10))
plt.imshow(frame_rgb)
plt.axis('off')
plt.show()
